# %%
# !uv pip install napari-ndev
# Out:
# Audited 1 package in 63ms

# %%
import napari
from napari.utils import nbscreenshot

viewer = napari.Viewer()

viewer.window.add_plugin_dock_widget('napari-ndev', 'nDev App')

nbscreenshot(viewer)
# Out:
# (<napari._qt.widgets.qt_viewer_dock_widget.QtViewerDockWidget at 0x2efccd83ad0>,
#  <Container ()>)

# %% [markdown]
# ![alt text](image.png)
